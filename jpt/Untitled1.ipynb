# %%
import pandas as pd
df = pd.read_csv('jpt.csv')
colold = df.columns
df.columns = df.columns.str.strip()
if 'Unnamed: 0' in df.columns:
    print('yes')
    df = df.drop(columns=['Unnamed: 0'])
print(df.columns)
# Out:
# yes
# Index(['N', 'SSIM', 'MSE'], dtype='object')
