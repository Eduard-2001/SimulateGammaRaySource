# %%
EXP_NAME = "EXP_0_1"

# %%
import torch; torch.manual_seed(0)
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader
from function.Dir import Dir
from function.Dataset import ImageDataset
from function.Loss import Custom_criterion
from function.Log import log
import importlib

VAE_module = importlib.import_module(f'function.VAE_{EXP_NAME}')
VAE = getattr(VAE_module, 'VAE')

NUM_TO_LEARN = 499 #训练集放入图片对数量
EPOCHS = 200 #参数1
BATCH_SIZE = 32 #参数2
LATENTDIM = 64 #参数3
LR_MAX = 5e-4
LR_MIN = 5e-6
mode = 1 #0代表STED_HC文件训练，1代表使用STED，对应ImageDataset里的 mode 参数。（STED出的模型对泛化能力弱，STED_HC对训练集的还原会有点失真）

DEVICE = 'cuda'
LOSS_PLOT = []
EPOCH_PLOT = []

# %%
name = f'{EPOCHS}epo_{BATCH_SIZE}bth_{LATENTDIM}latn'

#加载数据集
dataset = ImageDataset(NUM_TO_LEARN, mode)
dataloader = DataLoader(dataset, BATCH_SIZE, True)

#初始化VAE网络
vae = VAE(LATENTDIM).to(DEVICE)
vae = nn.DataParallel(vae) #将 VAE 包装成一个并行化模型，以便在多个 GPU 上并行地进行训练

#定义LOSS函数与优化器
criterion1 = nn.MSELoss()
criterion2 = Custom_criterion().cuda()
optimizer = torch.optim.AdamW(vae.parameters(), lr = LR_MAX)

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")
blurry_img_numpy = blurry_img[1].squeeze().detach().numpy()
print(blurry_img_numpy.min())
print(blurry_img_numpy.max())
print(blurry_img_numpy)
# Out:
# Batch 1:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 2:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 3:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 4:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 5:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 6:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 7:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 8:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 9:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 10:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 11:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 12:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 13:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 14:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 15:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 16:
# Blurry image shape: torch.Size([19, 1, 128, 128])
# Original image shape: torch.Size([19, 1, 128, 128])
# 0.0
# 1.0
# [[5.7019144e-01 5.6881207e-01 5.6807894e-01 ... 7.3353153e-01
#   7.3556274e-01 7.3610145e-01]
#  [5.6357431e-01 5.6251127e-01 5.6206471e-01 ... 7.1117187e-01
#   7.1316510e-01 7.1442884e-01]
#  [5.5831283e-01 5.5764467e-01 5.5744207e-01 ... 6.9217104e-01
#   6.9406492e-01 6.9596791e-01]
#  ...
#  [2.1307960e-03 3.3081102e-03 4.3855691e-03 ... 1.3319726e-02
#   1.2718640e-02 1.2153453e-02]
#  [1.3867642e-03 2.3100374e-03 3.1299163e-03 ... 1.1359111e-02
#   1.0972374e-02 1.0620601e-02]
#  [4.6618065e-04 1.1270043e-03 1.6998352e-03 ... 9.3988087e-03
#   9.2230784e-03 9.0727992e-03]]

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")

num_images_to_show = 5
# 创建一个包含两列的图像网格，每一列显示一张模糊图像和一张原始图像
fig, axes = plt.subplots(num_images_to_show, 2, figsize=(10, 2*num_images_to_show))
# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像和原始图像
    blurry_img_numpy = blurry_img[i].squeeze().detach().numpy()
    original_img_numpy = original_img[i].squeeze().detach().numpy()
    
    # 显示模糊图像
    axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')
    
    # 显示原始图像
    axes[i, 1].imshow(original_img_numpy)
    axes[i, 1].set_title('Original Image')
    axes[i, 1].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()
# Out:
# Batch 1:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 2:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 3:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 4:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 5:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 6:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 7:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 8:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 9:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 10:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 11:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 12:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 13:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 14:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 15:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 16:
# Blurry image shape: torch.Size([19, 1, 128, 128])
# Original image shape: torch.Size([19, 1, 128, 128])

# %%
def train(dataloader, num_epochs):
    with open(f'training.log', 'w') as nothing: # 清空原log
        pass
    log(f"Experiment name: {EXP_NAME}")
    for epoch in range(num_epochs):
        vae.train() # 切换成训练模式
        total_loss = 0.0
        current_lr = LR_MIN + 0.5 * (LR_MAX - LR_MIN) * (1 + np.cos(np.pi * epoch / EPOCHS))
        optimizer = torch.optim.AdamW(vae.parameters(), lr = current_lr)

        for _, (img_LR, img_HR) in enumerate(dataloader):
            # img_LR = torch.squeeze(img_LR,dim = 1).to(DEVICE)
            # img_HR = torch.squeeze(img_HR,dim = 1).to(DEVICE)
            img_LR = img_LR.to(DEVICE)
            img_HR = img_HR.to(DEVICE)
            img_SR, _, _ = vae(img_LR)
            img_SR = img_SR.to(DEVICE)
            # 这步为止，img_LR,img_HR,img_SR均是[batchsize,不知道是什么,宽，高]
            if epoch <= 500:
                loss = criterion1(img_SR, img_HR)
            if epoch > 500:
                loss = criterion2(img_SR, img_HR) # 每个BATCH的loss，64张图平均
            optimizer.zero_grad()
            loss.backward() # 最耗算力的一步
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader) # 每个EPOCH的loss，全部数据集的平均
        print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.6f}, Current_LR:{current_lr:.4f}")
        log(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.6f}, Current_LR:{current_lr:.4f}")

        LOSS_PLOT.append(total_loss)
        EPOCH_PLOT.append(epoch)
        # if epoch % 300 == 0:
        #     torch.save(vae.state_dict(), Dir.TEMP()+'/checkpoint.pth')

# %%
# for _, (img_LR, img_HR) in enumerate(dataloader):
#     img_SR, _, _ = vae(img_LR)
#     img_SR = img_SR.to(DEVICE)
#     print(img_SR.max())

# %%
print(f'DEVICE:{DEVICE}\n')
print(f'Training Start. \nExperiment name: {EXP_NAME}')
train(dataloader, EPOCHS)
print(f'\n Succsessfully done! Training log saved.')
# Out:
# DEVICE:cuda
#
# Training Start.
# Experiment name: EXP_0_1
# Epoch [1/200], Average Loss: 0.067144, Current_LR:0.0005
# Epoch [2/200], Average Loss: 0.055171, Current_LR:0.0005
# Epoch [3/200], Average Loss: 0.037183, Current_LR:0.0005
# Epoch [4/200], Average Loss: 0.023619, Current_LR:0.0005
# Epoch [5/200], Average Loss: 0.019194, Current_LR:0.0005
# Epoch [6/200], Average Loss: 0.015958, Current_LR:0.0005
# Epoch [7/200], Average Loss: 0.014510, Current_LR:0.0005
# Epoch [8/200], Average Loss: 0.013179, Current_LR:0.0005
# Epoch [9/200], Average Loss: 0.011758, Current_LR:0.0005
# Epoch [10/200], Average Loss: 0.010140, Current_LR:0.0005
# Epoch [11/200], Average Loss: 0.009227, Current_LR:0.0005
# Epoch [12/200], Average Loss: 0.008747, Current_LR:0.0005
# Epoch [13/200], Average Loss: 0.007766, Current_LR:0.0005
# Epoch [14/200], Average Loss: 0.007096, Current_LR:0.0005
# Epoch [15/200], Average Loss: 0.007050, Current_LR:0.0005
# Epoch [16/200], Average Loss: 0.006243, Current_LR:0.0005
# Epoch [17/200], Average Loss: 0.006159, Current_LR:0.0005
# Epoch [18/200], Average Loss: 0.005819, Current_LR:0.0005
# Epoch [19/200], Average Loss: 0.005885, Current_LR:0.0005
# Epoch [20/200], Average Loss: 0.005674, Current_LR:0.0005
# Epoch [21/200], Average Loss: 0.005649, Current_LR:0.0005
# Epoch [22/200], Average Loss: 0.005218, Current_LR:0.0005
# Epoch [23/200], Average Loss: 0.005265, Current_LR:0.0005
# Epoch [24/200], Average Loss: 0.005054, Current_LR:0.0005
# Epoch [25/200], Average Loss: 0.004641, Current_LR:0.0005
# Epoch [26/200], Average Loss: 0.004747, Current_LR:0.0005
# Epoch [27/200], Average Loss: 0.004784, Current_LR:0.0005
# Epoch [28/200], Average Loss: 0.004364, Current_LR:0.0005
# Epoch [29/200], Average Loss: 0.004497, Current_LR:0.0005
# Epoch [30/200], Average Loss: 0.004268, Current_LR:0.0005
# Epoch [31/200], Average Loss: 0.004387, Current_LR:0.0005
# Epoch [32/200], Average Loss: 0.004031, Current_LR:0.0005
# Epoch [33/200], Average Loss: 0.004107, Current_LR:0.0005
# Epoch [34/200], Average Loss: 0.004193, Current_LR:0.0005
# Epoch [35/200], Average Loss: 0.004134, Current_LR:0.0005
# Epoch [36/200], Average Loss: 0.003816, Current_LR:0.0005
# Epoch [37/200], Average Loss: 0.003987, Current_LR:0.0005
# Epoch [38/200], Average Loss: 0.003817, Current_LR:0.0005
# Epoch [39/200], Average Loss: 0.003628, Current_LR:0.0005
# Epoch [40/200], Average Loss: 0.003974, Current_LR:0.0005
# Epoch [41/200], Average Loss: 0.003547, Current_LR:0.0005
# Epoch [42/200], Average Loss: 0.003565, Current_LR:0.0005
# Epoch [43/200], Average Loss: 0.003429, Current_LR:0.0004
# Epoch [44/200], Average Loss: 0.003425, Current_LR:0.0004
# Epoch [45/200], Average Loss: 0.003383, Current_LR:0.0004
# Epoch [46/200], Average Loss: 0.003319, Current_LR:0.0004
# Epoch [47/200], Average Loss: 0.003397, Current_LR:0.0004
# Epoch [48/200], Average Loss: 0.003194, Current_LR:0.0004
# Epoch [49/200], Average Loss: 0.003068, Current_LR:0.0004
# Epoch [50/200], Average Loss: 0.003000, Current_LR:0.0004
# Epoch [51/200], Average Loss: 0.003061, Current_LR:0.0004
# Epoch [52/200], Average Loss: 0.002950, Current_LR:0.0004
# Epoch [53/200], Average Loss: 0.003119, Current_LR:0.0004
# Epoch [54/200], Average Loss: 0.002969, Current_LR:0.0004
# Epoch [55/200], Average Loss: 0.002865, Current_LR:0.0004
# Epoch [56/200], Average Loss: 0.002793, Current_LR:0.0004
# Epoch [57/200], Average Loss: 0.002724, Current_LR:0.0004
# Epoch [58/200], Average Loss: 0.002696, Current_LR:0.0004
# Epoch [59/200], Average Loss: 0.002650, Current_LR:0.0004
# Epoch [60/200], Average Loss: 0.002723, Current_LR:0.0004
# Epoch [61/200], Average Loss: 0.002733, Current_LR:0.0004
# Epoch [62/200], Average Loss: 0.002614, Current_LR:0.0004
# Epoch [63/200], Average Loss: 0.002568, Current_LR:0.0004
# Epoch [64/200], Average Loss: 0.002580, Current_LR:0.0004
# Epoch [65/200], Average Loss: 0.002469, Current_LR:0.0004
# Epoch [66/200], Average Loss: 0.002441, Current_LR:0.0004
# Epoch [67/200], Average Loss: 0.002519, Current_LR:0.0004
# Epoch [68/200], Average Loss: 0.002503, Current_LR:0.0004
# Epoch [69/200], Average Loss: 0.002419, Current_LR:0.0004
# Epoch [70/200], Average Loss: 0.002308, Current_LR:0.0004
# Epoch [71/200], Average Loss: 0.002344, Current_LR:0.0004
# Epoch [72/200], Average Loss: 0.002309, Current_LR:0.0004
# Epoch [73/200], Average Loss: 0.002267, Current_LR:0.0004
# Epoch [74/200], Average Loss: 0.002245, Current_LR:0.0004
# Epoch [75/200], Average Loss: 0.002209, Current_LR:0.0004
# Epoch [76/200], Average Loss: 0.002176, Current_LR:0.0003
# Epoch [77/200], Average Loss: 0.002193, Current_LR:0.0003
# Epoch [78/200], Average Loss: 0.002196, Current_LR:0.0003
# Epoch [79/200], Average Loss: 0.002233, Current_LR:0.0003
# Epoch [80/200], Average Loss: 0.002104, Current_LR:0.0003
# Epoch [81/200], Average Loss: 0.002122, Current_LR:0.0003
# Epoch [82/200], Average Loss: 0.002140, Current_LR:0.0003
# Epoch [83/200], Average Loss: 0.002067, Current_LR:0.0003
# Epoch [84/200], Average Loss: 0.002041, Current_LR:0.0003
# Epoch [85/200], Average Loss: 0.002045, Current_LR:0.0003
# Epoch [86/200], Average Loss: 0.002058, Current_LR:0.0003
# Epoch [87/200], Average Loss: 0.001970, Current_LR:0.0003
# Epoch [88/200], Average Loss: 0.001982, Current_LR:0.0003
# Epoch [89/200], Average Loss: 0.001940, Current_LR:0.0003
# Epoch [90/200], Average Loss: 0.001999, Current_LR:0.0003
# Epoch [91/200], Average Loss: 0.001958, Current_LR:0.0003
# Epoch [92/200], Average Loss: 0.001970, Current_LR:0.0003
# Epoch [93/200], Average Loss: 0.001912, Current_LR:0.0003
# Epoch [94/200], Average Loss: 0.001899, Current_LR:0.0003
# Epoch [95/200], Average Loss: 0.001874, Current_LR:0.0003
# Epoch [96/200], Average Loss: 0.001865, Current_LR:0.0003
# Epoch [97/200], Average Loss: 0.001875, Current_LR:0.0003
# Epoch [98/200], Average Loss: 0.001871, Current_LR:0.0003
# Epoch [99/200], Average Loss: 0.001783, Current_LR:0.0003
# Epoch [100/200], Average Loss: 0.001852, Current_LR:0.0003
# Epoch [101/200], Average Loss: 0.001843, Current_LR:0.0003
# Epoch [102/200], Average Loss: 0.001800, Current_LR:0.0002
# Epoch [103/200], Average Loss: 0.001793, Current_LR:0.0002
# Epoch [104/200], Average Loss: 0.001752, Current_LR:0.0002
# Epoch [105/200], Average Loss: 0.001754, Current_LR:0.0002
# Epoch [106/200], Average Loss: 0.001710, Current_LR:0.0002
# Epoch [107/200], Average Loss: 0.001688, Current_LR:0.0002
# Epoch [108/200], Average Loss: 0.001704, Current_LR:0.0002
# Epoch [109/200], Average Loss: 0.001710, Current_LR:0.0002
# Epoch [110/200], Average Loss: 0.001699, Current_LR:0.0002
# Epoch [111/200], Average Loss: 0.001656, Current_LR:0.0002
# Epoch [112/200], Average Loss: 0.001662, Current_LR:0.0002
# Epoch [113/200], Average Loss: 0.001638, Current_LR:0.0002
# Epoch [114/200], Average Loss: 0.001613, Current_LR:0.0002
# Epoch [115/200], Average Loss: 0.001628, Current_LR:0.0002
# Epoch [116/200], Average Loss: 0.001602, Current_LR:0.0002
# Epoch [117/200], Average Loss: 0.001594, Current_LR:0.0002
# Epoch [118/200], Average Loss: 0.001610, Current_LR:0.0002
# Epoch [119/200], Average Loss: 0.001595, Current_LR:0.0002
# Epoch [120/200], Average Loss: 0.001575, Current_LR:0.0002
# Epoch [121/200], Average Loss: 0.001565, Current_LR:0.0002
# Epoch [122/200], Average Loss: 0.001538, Current_LR:0.0002
# Epoch [123/200], Average Loss: 0.001562, Current_LR:0.0002
# Epoch [124/200], Average Loss: 0.001526, Current_LR:0.0002
# Epoch [125/200], Average Loss: 0.001522, Current_LR:0.0002
# Epoch [126/200], Average Loss: 0.001532, Current_LR:0.0002
# Epoch [127/200], Average Loss: 0.001523, Current_LR:0.0002
# Epoch [128/200], Average Loss: 0.001513, Current_LR:0.0002
# Epoch [129/200], Average Loss: 0.001498, Current_LR:0.0001
# Epoch [130/200], Average Loss: 0.001482, Current_LR:0.0001
# Epoch [131/200], Average Loss: 0.001480, Current_LR:0.0001
# Epoch [132/200], Average Loss: 0.001462, Current_LR:0.0001
# Epoch [133/200], Average Loss: 0.001467, Current_LR:0.0001
# Epoch [134/200], Average Loss: 0.001449, Current_LR:0.0001
# Epoch [135/200], Average Loss: 0.001442, Current_LR:0.0001
# Epoch [136/200], Average Loss: 0.001451, Current_LR:0.0001
# Epoch [137/200], Average Loss: 0.001444, Current_LR:0.0001
# Epoch [138/200], Average Loss: 0.001421, Current_LR:0.0001
# Epoch [139/200], Average Loss: 0.001433, Current_LR:0.0001
# Epoch [140/200], Average Loss: 0.001403, Current_LR:0.0001
# Epoch [141/200], Average Loss: 0.001398, Current_LR:0.0001
# Epoch [142/200], Average Loss: 0.001411, Current_LR:0.0001
# Epoch [143/200], Average Loss: 0.001411, Current_LR:0.0001
# Epoch [144/200], Average Loss: 0.001398, Current_LR:0.0001
# Epoch [145/200], Average Loss: 0.001391, Current_LR:0.0001
# Epoch [146/200], Average Loss: 0.001390, Current_LR:0.0001
# Epoch [147/200], Average Loss: 0.001383, Current_LR:0.0001
# Epoch [148/200], Average Loss: 0.001388, Current_LR:0.0001
# Epoch [149/200], Average Loss: 0.001373, Current_LR:0.0001
# Epoch [150/200], Average Loss: 0.001377, Current_LR:0.0001
# Epoch [151/200], Average Loss: 0.001350, Current_LR:0.0001
# Epoch [152/200], Average Loss: 0.001360, Current_LR:0.0001
# Epoch [153/200], Average Loss: 0.001352, Current_LR:0.0001
# Epoch [154/200], Average Loss: 0.001346, Current_LR:0.0001
# Epoch [155/200], Average Loss: 0.001341, Current_LR:0.0001
# Epoch [156/200], Average Loss: 0.001334, Current_LR:0.0001
# Epoch [157/200], Average Loss: 0.001333, Current_LR:0.0001
# Epoch [158/200], Average Loss: 0.001327, Current_LR:0.0001
# Epoch [159/200], Average Loss: 0.001329, Current_LR:0.0001
# Epoch [160/200], Average Loss: 0.001324, Current_LR:0.0001
# Epoch [161/200], Average Loss: 0.001314, Current_LR:0.0001
# Epoch [162/200], Average Loss: 0.001313, Current_LR:0.0001
# Epoch [163/200], Average Loss: 0.001317, Current_LR:0.0000
# Epoch [164/200], Average Loss: 0.001308, Current_LR:0.0000
# Epoch [165/200], Average Loss: 0.001313, Current_LR:0.0000
# Epoch [166/200], Average Loss: 0.001306, Current_LR:0.0000
# Epoch [167/200], Average Loss: 0.001298, Current_LR:0.0000
# Epoch [168/200], Average Loss: 0.001300, Current_LR:0.0000
# Epoch [169/200], Average Loss: 0.001291, Current_LR:0.0000
# Epoch [170/200], Average Loss: 0.001293, Current_LR:0.0000
# Epoch [171/200], Average Loss: 0.001293, Current_LR:0.0000
# Epoch [172/200], Average Loss: 0.001289, Current_LR:0.0000
# Epoch [173/200], Average Loss: 0.001285, Current_LR:0.0000
# Epoch [174/200], Average Loss: 0.001282, Current_LR:0.0000
# Epoch [175/200], Average Loss: 0.001283, Current_LR:0.0000
# Epoch [176/200], Average Loss: 0.001284, Current_LR:0.0000
# Epoch [177/200], Average Loss: 0.001282, Current_LR:0.0000
# Epoch [178/200], Average Loss: 0.001276, Current_LR:0.0000
# Epoch [179/200], Average Loss: 0.001275, Current_LR:0.0000
# Epoch [180/200], Average Loss: 0.001278, Current_LR:0.0000
# Epoch [181/200], Average Loss: 0.001276, Current_LR:0.0000
# Epoch [182/200], Average Loss: 0.001268, Current_LR:0.0000
# Epoch [183/200], Average Loss: 0.001268, Current_LR:0.0000
# Epoch [184/200], Average Loss: 0.001266, Current_LR:0.0000
# Epoch [185/200], Average Loss: 0.001263, Current_LR:0.0000
# Epoch [186/200], Average Loss: 0.001272, Current_LR:0.0000
# Epoch [187/200], Average Loss: 0.001262, Current_LR:0.0000
# Epoch [188/200], Average Loss: 0.001266, Current_LR:0.0000
# Epoch [189/200], Average Loss: 0.001263, Current_LR:0.0000
# Epoch [190/200], Average Loss: 0.001261, Current_LR:0.0000
# Epoch [191/200], Average Loss: 0.001262, Current_LR:0.0000
# Epoch [192/200], Average Loss: 0.001260, Current_LR:0.0000
# Epoch [193/200], Average Loss: 0.001261, Current_LR:0.0000
# Epoch [194/200], Average Loss: 0.001264, Current_LR:0.0000
# Epoch [195/200], Average Loss: 0.001257, Current_LR:0.0000
# Epoch [196/200], Average Loss: 0.001260, Current_LR:0.0000
# Epoch [197/200], Average Loss: 0.001258, Current_LR:0.0000
# Epoch [198/200], Average Loss: 0.001259, Current_LR:0.0000
# Epoch [199/200], Average Loss: 0.001262, Current_LR:0.0000
# Epoch [200/200], Average Loss: 0.001253, Current_LR:0.0000
#
#  Succsessfully done! Training log saved.

# %%
fig,ax = plt.subplots()
ax.plot(EPOCH_PLOT,LOSS_PLOT)
fig.savefig(f'../models/{EXP_NAME}_lossfig_{name}.png', dpi = 300) # 保存LOSS图片
print(f'LOSS fig saved at {Dir.models()}/{EXP_NAME}_lossfig_{name}.png')
LOSS_DATA = np.stack((np.array(EPOCH_PLOT),np.array(LOSS_PLOT)),axis=0)
np.save(f'../models/{EXP_NAME}_lossdata_{name}.npy',LOSS_DATA) # 保存LOSS数据
print(f'LOSS data saved at {Dir.models()}/{EXP_NAME}_lossdata_{name}.npy')
torch.save(vae.state_dict(), f'../models/{EXP_NAME}_model_{name}.pth') #保存模型pth
print(f'MODEL saved at {Dir.models()}/{EXP_NAME}_model_{name}.pth')
# Out:
# LOSS fig saved at ../outputs/trained_models/EXP_0_1_lossfig_200epo_32bth_64latn.png
# LOSS data saved at ../outputs/trained_models/EXP_0_1_lossdata_200epo_32bth_64latn.npy
# MODEL saved at ../outputs/trained_models/EXP_0_1_model_200epo_32bth_64latn.pth

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

def visualize_vae_effect(vae, dataloader, num_images, device):
    vae.eval()  # 切换到评估模式
    data_iter = iter(dataloader)
    
    # 获取一些图像
    img_LR, img_HR = next(data_iter)
    img_LR = img_LR.to(device)
    img_HR = img_HR.to(device)
    
    with torch.no_grad():
        img_SR, _, _ = vae(img_LR)
    
    # 移动到CPU并转换为numpy数组以进行可视化
    img_LR = img_LR.cpu()
    img_SR = img_SR.cpu()
    img_HR = img_HR.cpu()
    
    
    # 绘制图像
    fig, axes = plt.subplots(3, 1, figsize=(15, 15))
    axes[0].imshow(img_LR)
    axes[0].set_title('Input Images (LR)')
    axes[0].axis('off')
    
    axes[1].imshow(output_grid.permute(1, 2, 0).numpy())
    axes[1].set_title('Reconstructed Images (SR)')
    axes[1].axis('off')
    
    axes[2].imshow(real_grid.permute(1, 2, 0).numpy())
    axes[2].set_title('Real High-Resolution Images (HR)')
    axes[2].axis('off')
    
    plt.show()

# 在训练结束后调用该函数
visualize_vae_effect(vae, dataloader, num_images=8, device=DEVICE)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_140554/3778308308.py in <cell line: 39>()
#      37
#      38 # 在训练结束后调用该函数
# ---> 39 visualize_vae_effect(vae, dataloader, num_images=8, device=DEVICE)
#
# /tmp/ipykernel_140554/3778308308.py in visualize_vae_effect(vae, dataloader, num_images, device)
#      22     # 绘制图像
#      23     fig, axes = plt.subplots(3, 1, figsize=(15, 15))
# ---> 24     axes[0].imshow(img_LR)
#      25     axes[0].set_title('Input Images (LR)')
#      26     axes[0].axis('off')
#
# ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5757             self.set_aspect(aspect)
#    5758
# -> 5759         im.set_data(X)
#    5760         im.set_alpha(alpha)
#    5761         if im.get_clip_path() is None:
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in set_data(self, A)
#     721         if isinstance(A, PIL.Image.Image):
#     722             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723         self._A = self._normalize_image_array(A)
#     724         self._imcache = None
#     725         self.stale = True
#
# ~/.local/lib/python3.10/site-packages/matplotlib/image.py in _normalize_image_array(A)
#     691             A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     692         if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 693             raise TypeError(f"Invalid shape {A.shape} for image data")
#     694         if A.ndim == 3:
#     695             # If the input data has values outside the valid range (after
#
# TypeError: Invalid shape (32, 1, 128, 128) for image data

# %%
import torch
import matplotlib.pyplot as plt

vae.eval()  # 切换到评估模式

for _, (img_LR, img_HR) in enumerate(dataloader):
    img_SR, _, _ = vae(img_LR)
    img_SR = img_SR.cpu()

num_images_to_show = 5
# 创建一个包含三列的图像网格，每一列显示一张模糊图像、超分辨率图像和原始图像
fig, axes = plt.subplots(num_images_to_show, 3, figsize=(15, 3 * num_images_to_show))

# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像、超分辨率图像和原始图像
    blurry_img_numpy = img_LR[i].squeeze().detach().cpu().numpy()
    sr_img_numpy = img_SR[i].squeeze().detach().cpu().numpy()
    original_img_numpy = img_HR[i].squeeze().detach().cpu().numpy()
    
    # 显示模糊图像
    axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')

    # 显示超分辨率图像
    axes[i, 1].imshow(sr_img_numpy)
    axes[i, 1].set_title('SR Image')
    axes[i, 1].axis('off')
    
    # 显示原始图像
    axes[i, 2].imshow(original_img_numpy)
    axes[i, 2].set_title('Original Image')
    axes[i, 2].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()
