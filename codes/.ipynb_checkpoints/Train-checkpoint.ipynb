# %%
EXP_NAME = "EXP_0_1"

# %%
import torch; torch.manual_seed(0)
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader
from function.Dir import Dir
from function.Dataset import ImageDataset
from function.Loss import Custom_criterion
from function.Log import log
import importlib

VAE_module = importlib.import_module(f'function.VAE_{EXP_NAME}')
VAE = getattr(VAE_module, 'VAE')

NUM_TO_LEARN = 1500 #训练集放入图片对数量
EPOCHS = 200 #参数1
BATCH_SIZE = 32 #参数2
LATENTDIM = 64 #参数3
LR_MAX = 5e-4
LR_MIN = 5e-6
mode = 1 #0代表STED_HC文件训练，1代表使用STED，对应ImageDataset里的 mode 参数。（STED出的模型对泛化能力弱，STED_HC对训练集的还原会有点失真）

DEVICE = 'cuda'
LOSS_PLOT = []
EPOCH_PLOT = []

# %%
name = f'{EPOCHS}epo_{BATCH_SIZE}bth_{LATENTDIM}latn'

#加载数据集
dataset = ImageDataset(NUM_TO_LEARN, mode)
dataloader = DataLoader(dataset, BATCH_SIZE, True)

#初始化VAE网络
vae = VAE(LATENTDIM).to(DEVICE)
vae = nn.DataParallel(vae) #将 VAE 包装成一个并行化模型，以便在多个 GPU 上并行地进行训练

#定义LOSS函数与优化器
criterion1 = nn.MSELoss()
criterion2 = Custom_criterion().cuda()
optimizer = torch.optim.AdamW(vae.parameters(), lr = LR_MAX)

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    continue
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")
blurry_img_numpy = blurry_img[1].squeeze().detach().numpy()
print(blurry_img_numpy.min())
print(blurry_img_numpy.max())
print(blurry_img_numpy)
# Out:
# Batch 1:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 2:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 3:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 4:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 5:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 6:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 7:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 8:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 9:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 10:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 11:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 12:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 13:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 14:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 15:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 16:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 17:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 18:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 19:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 20:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 21:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 22:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 23:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 24:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 25:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 26:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 27:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 28:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 29:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 30:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 31:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 32:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 33:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 34:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 35:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 36:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 37:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 38:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 39:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 40:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 41:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 42:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 43:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 44:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 45:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 46:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 47:
# Blurry image shape: torch.Size([28, 1, 128, 128])
# Original image shape: torch.Size([28, 1, 128, 128])
# 0.0
# 1.0
# [[0.44596538 0.42342398 0.38910455 ... 0.11216469 0.10457052 0.09844192]
#  [0.43247765 0.4083506  0.37497708 ... 0.11215302 0.10384873 0.09710072]
#  [0.41780013 0.39322165 0.36134666 ... 0.11100259 0.10288585 0.09620998]
#  ...
#  [0.04453747 0.03858374 0.03559708 ... 0.15861098 0.15294363 0.14907797]
#  [0.05175915 0.04441121 0.04035022 ... 0.1494463  0.14289391 0.13816145]
#  [0.05730753 0.04912721 0.04430149 ... 0.14186436 0.13450101 0.12892602]]

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    continue
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")

num_images_to_show = 5
# 创建一个包含两列的图像网格，每一列显示一张模糊图像和一张原始图像
fig, axes = plt.subplots(num_images_to_show, 2, figsize=(10, 2*num_images_to_show))
# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像和原始图像
    blurry_img_numpy = blurry_img[i].squeeze().detach().numpy()
    original_img_numpy = original_img[i].squeeze().detach().numpy()
    
    # 显示模糊图像
    axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')
    
    # 显示原始图像
    axes[i, 1].imshow(original_img_numpy)
    axes[i, 1].set_title('Original Image')
    axes[i, 1].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()
# Out:
# Batch 1:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 2:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 3:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 4:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 5:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 6:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 7:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 8:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 9:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 10:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 11:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 12:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 13:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 14:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 15:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 16:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 17:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 18:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 19:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 20:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 21:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 22:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 23:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 24:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 25:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 26:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 27:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 28:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 29:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 30:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 31:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 32:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 33:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 34:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 35:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 36:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 37:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 38:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 39:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 40:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 41:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 42:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 43:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 44:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 45:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 46:
# Blurry image shape: torch.Size([32, 1, 128, 128])
# Original image shape: torch.Size([32, 1, 128, 128])
# Batch 47:
# Blurry image shape: torch.Size([28, 1, 128, 128])
# Original image shape: torch.Size([28, 1, 128, 128])

# %%
def train(dataloader, num_epochs):
    with open(f'training.log', 'w') as nothing: # 清空原log
        pass
    log(f"Experiment name: {EXP_NAME}")
    for epoch in range(num_epochs):
        vae.train() # 切换成训练模式
        total_loss = 0.0
        current_lr = LR_MIN + 0.5 * (LR_MAX - LR_MIN) * (1 + np.cos(np.pi * epoch / EPOCHS))
        optimizer = torch.optim.AdamW(vae.parameters(), lr = current_lr)

        for _, (img_LR, img_HR) in enumerate(dataloader):
            # img_LR = torch.squeeze(img_LR,dim = 1).to(DEVICE)
            # img_HR = torch.squeeze(img_HR,dim = 1).to(DEVICE)
            img_LR = img_LR.to(DEVICE)
            img_HR = img_HR.to(DEVICE)
            img_SR, _, _ = vae(img_LR)
            img_SR = img_SR.to(DEVICE)
            # 这步为止，img_LR,img_HR,img_SR均是[batchsize,不知道是什么,宽，高]
            if epoch <= 500:
                loss = criterion1(img_SR, img_HR)
            if epoch > 500:
                loss = criterion2(img_SR, img_HR) # 每个BATCH的loss，64张图平均
            optimizer.zero_grad()
            loss.backward() # 最耗算力的一步
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader) # 每个EPOCH的loss，全部数据集的平均
        print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.6f}, Current_LR:{current_lr:.4f}")
        log(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.6f}, Current_LR:{current_lr:.4f}")

        LOSS_PLOT.append(total_loss)
        EPOCH_PLOT.append(epoch)
        # if epoch % 300 == 0:
        #     torch.save(vae.state_dict(), Dir.TEMP()+'/checkpoint.pth')

# %%
# for _, (img_LR, img_HR) in enumerate(dataloader):
#     img_SR, _, _ = vae(img_LR)
#     img_SR = img_SR.to(DEVICE)
#     print(img_SR.max())

# %%
print(f'DEVICE:{DEVICE}\n')
print(f'Training Start. \nExperiment name: {EXP_NAME}')
train(dataloader, EPOCHS)
print(f'\n Succsessfully done! Training log saved.')
# Out:
# DEVICE:cuda
#
# Training Start.
# Experiment name: EXP_0_1
# Epoch [1/200], Average Loss: 0.053550, Current_LR:0.0005
# Epoch [2/200], Average Loss: 0.021514, Current_LR:0.0005
# Epoch [3/200], Average Loss: 0.014860, Current_LR:0.0005
# Epoch [4/200], Average Loss: 0.012241, Current_LR:0.0005
# Epoch [5/200], Average Loss: 0.010071, Current_LR:0.0005
# Epoch [6/200], Average Loss: 0.009091, Current_LR:0.0005
# Epoch [7/200], Average Loss: 0.008471, Current_LR:0.0005
# Epoch [8/200], Average Loss: 0.007914, Current_LR:0.0005
# Epoch [9/200], Average Loss: 0.007667, Current_LR:0.0005
# Epoch [10/200], Average Loss: 0.007139, Current_LR:0.0005
# Epoch [11/200], Average Loss: 0.006981, Current_LR:0.0005
# Epoch [12/200], Average Loss: 0.006302, Current_LR:0.0005
# Epoch [13/200], Average Loss: 0.005934, Current_LR:0.0005
# Epoch [14/200], Average Loss: 0.006103, Current_LR:0.0005
# Epoch [15/200], Average Loss: 0.005620, Current_LR:0.0005
# Epoch [16/200], Average Loss: 0.005385, Current_LR:0.0005
# Epoch [17/200], Average Loss: 0.005432, Current_LR:0.0005
# Epoch [18/200], Average Loss: 0.005111, Current_LR:0.0005
# Epoch [19/200], Average Loss: 0.004831, Current_LR:0.0005
# Epoch [20/200], Average Loss: 0.004618, Current_LR:0.0005
# Epoch [21/200], Average Loss: 0.004669, Current_LR:0.0005
# Epoch [22/200], Average Loss: 0.004312, Current_LR:0.0005
# Epoch [23/200], Average Loss: 0.004346, Current_LR:0.0005
# Epoch [24/200], Average Loss: 0.004198, Current_LR:0.0005
# Epoch [25/200], Average Loss: 0.004019, Current_LR:0.0005
# Epoch [26/200], Average Loss: 0.003881, Current_LR:0.0005
# Epoch [27/200], Average Loss: 0.003890, Current_LR:0.0005
# Epoch [28/200], Average Loss: 0.003811, Current_LR:0.0005
# Epoch [29/200], Average Loss: 0.003562, Current_LR:0.0005
# Epoch [30/200], Average Loss: 0.003512, Current_LR:0.0005
# Epoch [31/200], Average Loss: 0.003508, Current_LR:0.0005
# Epoch [32/200], Average Loss: 0.003325, Current_LR:0.0005
# Epoch [33/200], Average Loss: 0.003311, Current_LR:0.0005
# Epoch [34/200], Average Loss: 0.003211, Current_LR:0.0005
# Epoch [35/200], Average Loss: 0.003031, Current_LR:0.0005
# Epoch [36/200], Average Loss: 0.002971, Current_LR:0.0005
# Epoch [37/200], Average Loss: 0.002906, Current_LR:0.0005
# Epoch [38/200], Average Loss: 0.002771, Current_LR:0.0005
# Epoch [39/200], Average Loss: 0.002711, Current_LR:0.0005
# Epoch [40/200], Average Loss: 0.002759, Current_LR:0.0005
# Epoch [41/200], Average Loss: 0.002728, Current_LR:0.0005
# Epoch [42/200], Average Loss: 0.002600, Current_LR:0.0005
# Epoch [43/200], Average Loss: 0.002589, Current_LR:0.0004
# Epoch [44/200], Average Loss: 0.002549, Current_LR:0.0004
# Epoch [45/200], Average Loss: 0.002416, Current_LR:0.0004
# Epoch [46/200], Average Loss: 0.002401, Current_LR:0.0004
# Epoch [47/200], Average Loss: 0.002283, Current_LR:0.0004
# Epoch [48/200], Average Loss: 0.002359, Current_LR:0.0004
# Epoch [49/200], Average Loss: 0.002229, Current_LR:0.0004
# Epoch [50/200], Average Loss: 0.002197, Current_LR:0.0004
# Epoch [51/200], Average Loss: 0.002199, Current_LR:0.0004
# Epoch [52/200], Average Loss: 0.002086, Current_LR:0.0004
# Epoch [53/200], Average Loss: 0.002085, Current_LR:0.0004
# Epoch [54/200], Average Loss: 0.002010, Current_LR:0.0004
# Epoch [55/200], Average Loss: 0.001999, Current_LR:0.0004
# Epoch [56/200], Average Loss: 0.001993, Current_LR:0.0004
# Epoch [57/200], Average Loss: 0.001895, Current_LR:0.0004
# Epoch [58/200], Average Loss: 0.001828, Current_LR:0.0004
# Epoch [59/200], Average Loss: 0.001800, Current_LR:0.0004
# Epoch [60/200], Average Loss: 0.001863, Current_LR:0.0004
# Epoch [61/200], Average Loss: 0.001827, Current_LR:0.0004
# Epoch [62/200], Average Loss: 0.001815, Current_LR:0.0004
# Epoch [63/200], Average Loss: 0.001762, Current_LR:0.0004
# Epoch [64/200], Average Loss: 0.001725, Current_LR:0.0004
# Epoch [65/200], Average Loss: 0.001658, Current_LR:0.0004
# Epoch [66/200], Average Loss: 0.001674, Current_LR:0.0004
# Epoch [67/200], Average Loss: 0.001599, Current_LR:0.0004
# Epoch [68/200], Average Loss: 0.001560, Current_LR:0.0004
# Epoch [69/200], Average Loss: 0.001578, Current_LR:0.0004
# Epoch [70/200], Average Loss: 0.001549, Current_LR:0.0004
# Epoch [71/200], Average Loss: 0.001487, Current_LR:0.0004
# Epoch [72/200], Average Loss: 0.001474, Current_LR:0.0004
# Epoch [73/200], Average Loss: 0.001511, Current_LR:0.0004
# Epoch [74/200], Average Loss: 0.001428, Current_LR:0.0004
# Epoch [75/200], Average Loss: 0.001435, Current_LR:0.0004
# Epoch [76/200], Average Loss: 0.001393, Current_LR:0.0003
# Epoch [77/200], Average Loss: 0.001385, Current_LR:0.0003
# Epoch [78/200], Average Loss: 0.001356, Current_LR:0.0003
# Epoch [79/200], Average Loss: 0.001352, Current_LR:0.0003
# Epoch [80/200], Average Loss: 0.001362, Current_LR:0.0003
# Epoch [81/200], Average Loss: 0.001297, Current_LR:0.0003
# Epoch [82/200], Average Loss: 0.001276, Current_LR:0.0003
# Epoch [83/200], Average Loss: 0.001292, Current_LR:0.0003
# Epoch [84/200], Average Loss: 0.001237, Current_LR:0.0003
# Epoch [85/200], Average Loss: 0.001235, Current_LR:0.0003
# Epoch [86/200], Average Loss: 0.001237, Current_LR:0.0003
# Epoch [87/200], Average Loss: 0.001224, Current_LR:0.0003
# Epoch [88/200], Average Loss: 0.001238, Current_LR:0.0003
# Epoch [89/200], Average Loss: 0.001181, Current_LR:0.0003
# Epoch [90/200], Average Loss: 0.001190, Current_LR:0.0003
# Epoch [91/200], Average Loss: 0.001166, Current_LR:0.0003
# Epoch [92/200], Average Loss: 0.001159, Current_LR:0.0003
# Epoch [93/200], Average Loss: 0.001127, Current_LR:0.0003
# Epoch [94/200], Average Loss: 0.001127, Current_LR:0.0003
# Epoch [95/200], Average Loss: 0.001104, Current_LR:0.0003
# Epoch [96/200], Average Loss: 0.001113, Current_LR:0.0003
# Epoch [97/200], Average Loss: 0.001098, Current_LR:0.0003
# Epoch [98/200], Average Loss: 0.001059, Current_LR:0.0003
# Epoch [99/200], Average Loss: 0.001073, Current_LR:0.0003
# Epoch [100/200], Average Loss: 0.001064, Current_LR:0.0003
# Epoch [101/200], Average Loss: 0.001031, Current_LR:0.0003
# Epoch [102/200], Average Loss: 0.001047, Current_LR:0.0002
# Epoch [103/200], Average Loss: 0.001013, Current_LR:0.0002
# Epoch [104/200], Average Loss: 0.001003, Current_LR:0.0002
# Epoch [105/200], Average Loss: 0.001015, Current_LR:0.0002
# Epoch [106/200], Average Loss: 0.001001, Current_LR:0.0002
# Epoch [107/200], Average Loss: 0.000972, Current_LR:0.0002
# Epoch [108/200], Average Loss: 0.000981, Current_LR:0.0002
# Epoch [109/200], Average Loss: 0.000960, Current_LR:0.0002
# Epoch [110/200], Average Loss: 0.000955, Current_LR:0.0002
# Epoch [111/200], Average Loss: 0.000954, Current_LR:0.0002
# Epoch [112/200], Average Loss: 0.000940, Current_LR:0.0002
# Epoch [113/200], Average Loss: 0.000926, Current_LR:0.0002
# Epoch [114/200], Average Loss: 0.000933, Current_LR:0.0002
# Epoch [115/200], Average Loss: 0.000908, Current_LR:0.0002
# Epoch [116/200], Average Loss: 0.000910, Current_LR:0.0002
# Epoch [117/200], Average Loss: 0.000900, Current_LR:0.0002
# Epoch [118/200], Average Loss: 0.000901, Current_LR:0.0002
# Epoch [119/200], Average Loss: 0.000893, Current_LR:0.0002
# Epoch [120/200], Average Loss: 0.000890, Current_LR:0.0002
# Epoch [121/200], Average Loss: 0.000876, Current_LR:0.0002
# Epoch [122/200], Average Loss: 0.000869, Current_LR:0.0002
# Epoch [123/200], Average Loss: 0.000869, Current_LR:0.0002
# Epoch [124/200], Average Loss: 0.000857, Current_LR:0.0002
# Epoch [125/200], Average Loss: 0.000855, Current_LR:0.0002
# Epoch [126/200], Average Loss: 0.000840, Current_LR:0.0002
# Epoch [127/200], Average Loss: 0.000835, Current_LR:0.0002
# Epoch [128/200], Average Loss: 0.000832, Current_LR:0.0002
# Epoch [129/200], Average Loss: 0.000829, Current_LR:0.0001
# Epoch [130/200], Average Loss: 0.000821, Current_LR:0.0001
# Epoch [131/200], Average Loss: 0.000816, Current_LR:0.0001
# Epoch [132/200], Average Loss: 0.000811, Current_LR:0.0001
# Epoch [133/200], Average Loss: 0.000803, Current_LR:0.0001
# Epoch [134/200], Average Loss: 0.000804, Current_LR:0.0001
# Epoch [135/200], Average Loss: 0.000795, Current_LR:0.0001
# Epoch [136/200], Average Loss: 0.000793, Current_LR:0.0001
# Epoch [137/200], Average Loss: 0.000786, Current_LR:0.0001
# Epoch [138/200], Average Loss: 0.000783, Current_LR:0.0001
# Epoch [139/200], Average Loss: 0.000783, Current_LR:0.0001
# Epoch [140/200], Average Loss: 0.000773, Current_LR:0.0001
# Epoch [141/200], Average Loss: 0.000771, Current_LR:0.0001
# Epoch [142/200], Average Loss: 0.000767, Current_LR:0.0001
# Epoch [143/200], Average Loss: 0.000762, Current_LR:0.0001
# Epoch [144/200], Average Loss: 0.000759, Current_LR:0.0001
# Epoch [145/200], Average Loss: 0.000755, Current_LR:0.0001
# Epoch [146/200], Average Loss: 0.000751, Current_LR:0.0001
# Epoch [147/200], Average Loss: 0.000747, Current_LR:0.0001
# Epoch [148/200], Average Loss: 0.000745, Current_LR:0.0001
# Epoch [149/200], Average Loss: 0.000741, Current_LR:0.0001
# Epoch [150/200], Average Loss: 0.000739, Current_LR:0.0001
# Epoch [151/200], Average Loss: 0.000737, Current_LR:0.0001
# Epoch [152/200], Average Loss: 0.000732, Current_LR:0.0001
# Epoch [153/200], Average Loss: 0.000730, Current_LR:0.0001
# Epoch [154/200], Average Loss: 0.000729, Current_LR:0.0001
# Epoch [155/200], Average Loss: 0.000724, Current_LR:0.0001
# Epoch [156/200], Average Loss: 0.000722, Current_LR:0.0001
# Epoch [157/200], Average Loss: 0.000719, Current_LR:0.0001
# Epoch [158/200], Average Loss: 0.000718, Current_LR:0.0001
# Epoch [159/200], Average Loss: 0.000716, Current_LR:0.0001
# Epoch [160/200], Average Loss: 0.000712, Current_LR:0.0001
# Epoch [161/200], Average Loss: 0.000711, Current_LR:0.0001
# Epoch [162/200], Average Loss: 0.000708, Current_LR:0.0001
# Epoch [163/200], Average Loss: 0.000707, Current_LR:0.0000
# Epoch [164/200], Average Loss: 0.000706, Current_LR:0.0000
# Epoch [165/200], Average Loss: 0.000703, Current_LR:0.0000
# Epoch [166/200], Average Loss: 0.000701, Current_LR:0.0000
# Epoch [167/200], Average Loss: 0.000699, Current_LR:0.0000
# Epoch [168/200], Average Loss: 0.000698, Current_LR:0.0000
# Epoch [169/200], Average Loss: 0.000696, Current_LR:0.0000
# Epoch [170/200], Average Loss: 0.000694, Current_LR:0.0000
# Epoch [171/200], Average Loss: 0.000693, Current_LR:0.0000
# Epoch [172/200], Average Loss: 0.000692, Current_LR:0.0000
# Epoch [173/200], Average Loss: 0.000691, Current_LR:0.0000
# Epoch [174/200], Average Loss: 0.000689, Current_LR:0.0000
# Epoch [175/200], Average Loss: 0.000688, Current_LR:0.0000
# Epoch [176/200], Average Loss: 0.000687, Current_LR:0.0000
# Epoch [177/200], Average Loss: 0.000686, Current_LR:0.0000
# Epoch [178/200], Average Loss: 0.000685, Current_LR:0.0000
# Epoch [179/200], Average Loss: 0.000684, Current_LR:0.0000
# Epoch [180/200], Average Loss: 0.000683, Current_LR:0.0000
# Epoch [181/200], Average Loss: 0.000683, Current_LR:0.0000
# Epoch [182/200], Average Loss: 0.000681, Current_LR:0.0000
# Epoch [183/200], Average Loss: 0.000681, Current_LR:0.0000
# Epoch [184/200], Average Loss: 0.000680, Current_LR:0.0000
# Epoch [185/200], Average Loss: 0.000679, Current_LR:0.0000
# Epoch [186/200], Average Loss: 0.000678, Current_LR:0.0000
# Epoch [187/200], Average Loss: 0.000678, Current_LR:0.0000
# Epoch [188/200], Average Loss: 0.000678, Current_LR:0.0000
# Epoch [189/200], Average Loss: 0.000677, Current_LR:0.0000
# Epoch [190/200], Average Loss: 0.000676, Current_LR:0.0000
# Epoch [191/200], Average Loss: 0.000676, Current_LR:0.0000
# Epoch [192/200], Average Loss: 0.000676, Current_LR:0.0000
# Epoch [193/200], Average Loss: 0.000675, Current_LR:0.0000
# Epoch [194/200], Average Loss: 0.000675, Current_LR:0.0000
# Epoch [195/200], Average Loss: 0.000675, Current_LR:0.0000
# Epoch [196/200], Average Loss: 0.000674, Current_LR:0.0000
# Epoch [197/200], Average Loss: 0.000674, Current_LR:0.0000
# Epoch [198/200], Average Loss: 0.000674, Current_LR:0.0000
# Epoch [199/200], Average Loss: 0.000673, Current_LR:0.0000
# Epoch [200/200], Average Loss: 0.000673, Current_LR:0.0000
#
#  Succsessfully done! Training log saved.

# %%
fig,ax = plt.subplots()
ax.plot(EPOCH_PLOT,LOSS_PLOT)
fig.savefig(f'../models/{EXP_NAME}_lossfig_{name}.png', dpi = 300) # 保存LOSS图片
print(f'LOSS fig saved at {Dir.models()}/{EXP_NAME}_lossfig_{name}.png')
LOSS_DATA = np.stack((np.array(EPOCH_PLOT),np.array(LOSS_PLOT)),axis=0)
np.save(f'../models/{EXP_NAME}_lossdata_{name}.npy',LOSS_DATA) # 保存LOSS数据
print(f'LOSS data saved at {Dir.models()}/{EXP_NAME}_lossdata_{name}.npy')
torch.save(vae.state_dict(), f'../models/{EXP_NAME}_model_{name}.pth') #保存模型pth
print(f'MODEL saved at {Dir.models()}/{EXP_NAME}_model_{name}.pth')
# Out:
# LOSS fig saved at ../outputs/trained_models/EXP_0_1_lossfig_200epo_32bth_64latn.png
# LOSS data saved at ../outputs/trained_models/EXP_0_1_lossdata_200epo_32bth_64latn.npy
# MODEL saved at ../outputs/trained_models/EXP_0_1_model_200epo_32bth_64latn.pth

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

def visualize_vae_effect(vae, dataloader, num_images, device):
    vae.eval()  # 切换到评估模式
    data_iter = iter(dataloader)
    
    # 获取一些图像
    img_LR, img_HR = next(data_iter)
    img_LR = img_LR.to(device)
    img_HR = img_HR.to(device)
    
    with torch.no_grad():
        img_SR, _, _ = vae(img_LR)
    
    # 移动到CPU并转换为numpy数组以进行可视化
    img_LR = img_LR.cpu()
    img_SR = img_SR.cpu()
    img_HR = img_HR.cpu()
    
    
    # 绘制图像
    fig, axes = plt.subplots(3, 1, figsize=(15, 15))
    axes[0].imshow(img_LR)
    axes[0].set_title('Input Images (LR)')
    axes[0].axis('off')
    
    axes[1].imshow(output_grid.permute(1, 2, 0).numpy())
    axes[1].set_title('Reconstructed Images (SR)')
    axes[1].axis('off')
    
    axes[2].imshow(real_grid.permute(1, 2, 0).numpy())
    axes[2].set_title('Real High-Resolution Images (HR)')
    axes[2].axis('off')
    
    plt.show()

# 在训练结束后调用该函数
visualize_vae_effect(vae, dataloader, num_images=8, device=DEVICE)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 39
#      36     plt.show()
#      38 # 在训练结束后调用该函数
# ---> 39 visualize_vae_effect(vae, dataloader, num_images=8, device=DEVICE)
#
# Cell In[10], line 24, in visualize_vae_effect(vae, dataloader, num_images, device)
#      22 # 绘制图像
#      23 fig, axes = plt.subplots(3, 1, figsize=(15, 15))
# ---> 24 axes[0].imshow(img_LR)
#      25 axes[0].set_title('Input Images (LR)')
#      26 axes[0].axis('off')
#
# File ~/.torchenv/lib64/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/.torchenv/lib64/python3.12/site-packages/matplotlib/axes/_axes.py:5895, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5892 if aspect is not None:
#    5893     self.set_aspect(aspect)
# -> 5895 im.set_data(X)
#    5896 im.set_alpha(alpha)
#    5897 if im.get_clip_path() is None:
#    5898     # image does not already have clipping set, clip to Axes patch
#
# File ~/.torchenv/lib64/python3.12/site-packages/matplotlib/image.py:729, in _ImageBase.set_data(self, A)
#     727 if isinstance(A, PIL.Image.Image):
#     728     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 729 self._A = self._normalize_image_array(A)
#     730 self._imcache = None
#     731 self.stale = True
#
# File ~/.torchenv/lib64/python3.12/site-packages/matplotlib/image.py:697, in _ImageBase._normalize_image_array(A)
#     695     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     696 if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 697     raise TypeError(f"Invalid shape {A.shape} for image data")
#     698 if A.ndim == 3:
#     699     # If the input data has values outside the valid range (after
#     700     # normalisation), we issue a warning and then clip X to the bounds
#     701     # - otherwise casting wraps extreme values, hiding outliers and
#     702     # making reliable interpretation impossible.
#     703     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (32, 1, 128, 128) for image data

# %%
import torch
import matplotlib.pyplot as plt

vae.eval()  # 切换到评估模式

for _, (img_LR, img_HR) in enumerate(dataloader):
    img_SR, _, _ = vae(img_LR)
    img_SR = img_SR.cpu()

num_images_to_show = 5
# 创建一个包含三列的图像网格，每一列显示一张模糊图像、超分辨率图像和原始图像
fig, axes = plt.subplots(num_images_to_show, 3, figsize=(15, 3 * num_images_to_show))

# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像、超分辨率图像和原始图像
    blurry_img_numpy = img_LR[i].squeeze().detach().cpu().numpy()
    sr_img_numpy = img_SR[i].squeeze().detach().cpu().numpy()
    original_img_numpy = img_HR[i].squeeze().detach().cpu().numpy()
    
    # 显示模糊图像
    axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')

    # 显示超分辨率图像
    axes[i, 1].imshow(sr_img_numpy)
    axes[i, 1].set_title('SR Image')
    axes[i, 1].axis('off')
    
    # 显示原始图像
    axes[i, 2].imshow(original_img_numpy)
    axes[i, 2].set_title('Original Image')
    axes[i, 2].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()
